# %%
import psi4
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# # Supplementing Experimental Data With Theory
#
# You will want to save a copy of this notebook to send in, but they will not be graded.
#
# In nearly all experiments, we did some amount of computational chemistry to support or enhance our experimental findings. This computational work entailed running quantum mechanical computations, rather than just data analysis (though we've certainly done plenty of that.
#
# In your final written reports, you are required to combine some element of computational chemistry with your experimental data. Today, we will consider how to do this effectively.

# %% [markdown]
# ## I. The Bomb Calorimetry Experiment
#
# In the bomb calorimetry experiment, we did not perform any computations. Could we have? With your lab group, brainstorm and answer the questions below:
#
#  1. What was the main goal(s) of the bomb calorimetry experiment?
#  2. Are there any questions, large or small, that are still unanswered or unsupported with the data we obtained?
#  3. Using your knowledge from computations done in other experiments, are there any useful quantities in this lab that you think could be computed with theoretical computation? What are they?

# %% [markdown]
# With your lab group, devise a procedure to obtain any useful quantities using chemical theory, be specific in each step.

# %% [markdown]
# In the cells that follow, execute your procedure. You may add or remove cells as needed.

# %% [markdown]
# ## II.  Your Written Report
#
# In the space below, summarize the experiment you are using for your written report, and summarize any computational data we have for that experiment.

# %% [markdown]
# Are there any additional unanswered questions about the experiment you have chosen (even if its the bomb one, anything we didn't do above?)? Do you think there is any additional computational data that may be helpful in the main purpose of the experiment? If you'd like, find one or more classmates who have selected the same lab to answer these questions.

# %% [markdown]
# Again, devise a brief protocol to obtain some new computational data for your report. You are free (encouraged) to consult your peers and to consult me.

# %% [markdown]
# Execute your protocol below:
